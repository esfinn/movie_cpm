# %%
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
import pandas as pd
import h5py
import seaborn as sns

# %%
top_dir = "/Users/finnes/Documents/HCP_7T/"
list_of_dfs = ['unres_behav_data.csv', 'res_behav_data.csv', 'emot_pc_scores.csv', 'cogn_pc_scores.csv', 'pers_pc_scores.csv', 'asr_pc_scores.csv', 'neo_pc_scores.csv', 'motion_data.csv', 'tod_data.csv']

# %%
for d,df in enumerate(list_of_dfs):
    tmp = pd.read_csv(top_dir+df, dtype={'Subject': 'str'})
    tmp.set_index("Subject", inplace=True)
    print('Doing df {}...number of columns in this df: {}'.format(df, tmp.shape[1]))
    
    if d==0:
        behav_data = tmp
    else:
        # behav_data = behav_data.join(tmp, how='outer')
        behav_data = pd.concat([behav_data, tmp], axis=1)
# Out:
# Doing df unres_behav_data.csv...number of columns in this df: 382
# Doing df res_behav_data.csv...number of columns in this df: 200
# Doing df emot_pc_scores.csv...number of columns in this df: 17
# Doing df cogn_pc_scores.csv...number of columns in this df: 12
# Doing df pers_pc_scores.csv...number of columns in this df: 5
# Doing df asr_pc_scores.csv...number of columns in this df: 22
# Doing df neo_pc_scores.csv...number of columns in this df: 60
# Doing df motion_data.csv...number of columns in this df: 44
# Doing df tod_data.csv...number of columns in this df: 16

# %%
behav_data.shape
# Out:
# (184, 758)

# %%
behav_data.index.rename("Subject", inplace=True)
behav_data.head()
# Out:
#         Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# Subject
# 100610     S900         Q08      M  26-30              True         2
# 102311     S500         Q06      F  26-30              True         1
# 102816       Q3         Q03      F  26-30              True         1
# 104416     S900         Q09      F  31-35              True         2
# 105923     MEG2         Q07      F  31-35              True         2
#
#          T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl  3T_Full_Task_fMRI  \
# Subject
# 100610          1                 4                100.0               True
# 102311          1                 4                100.0               True
# 102816          1                 4                100.0               True
# 104416          2                 4                100.0               True
# 105923          2                 4                100.0               True
#
#          ...  REST3_AcquisitionTime  REST4_AcquisitionTime  \
# ...

# %%
behav_data.to_csv('/Volumes/HCP_preproc/7T_movie/cpm/data/all_behav.csv')
behav_data.to_csv('all_behav.csv')

# %%
print(behav_data.isna().sum())
# Out:
# Release                     0
# Acquisition                 0
# Gender                      0
# Age                         0
# 3T_Full_MR_Compl            0
#                            ..
# MOVIE4_TimeFromLocalizer    8
# REST1_TimeFromLocalizer     8
# REST2_TimeFromLocalizer     8
# REST3_TimeFromLocalizer     8
# REST4_TimeFromLocalizer     8
# Length: 758, dtype: int64
