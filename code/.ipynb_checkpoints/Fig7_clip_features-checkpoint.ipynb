# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
import h5py
import itertools
import operator
import glob
import seaborn as sns
from adjustText import adjust_text
import types

from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression

# %%
video_tr_lookup = pd.read_csv('videoclip_tr_lookup.csv')
video_tr_lookup.head()
# Out:
#    clipno_overall           run  clipno_in_run    clip_name  start_tr  \
# 0               1  MOVIE1_7T_AP              1       twomen        20
# 1               2  MOVIE1_7T_AP              2  bridgeville       285
# 2               3  MOVIE1_7T_AP              3      pockets       526
# 3               4  MOVIE1_7T_AP              4     overcome       735
# 4               5  MOVIE1_7T_AP              5  testretest1       818
#
#    stop_tr  duration Unnamed: 7
# 0      265       245      04:05
# 1      506       221      03:41
# 2      714       188      03:08
# 3      798        63      01:03
# 4      901        83      01:23

# %%
f = h5py.File('../data/7T_movie_resources/WordNetFeatures.hdf5', 'r')
list(f.keys())
# Out:
# ['MOVIE1_CC1',
#  'MOVIE1_CC1_est',
#  'MOVIE1_CC1_val',
#  'MOVIE2_HO1',
#  'MOVIE2_HO1_est',
#  'MOVIE2_HO1_val',
#  'MOVIE3_CC2',
#  'MOVIE3_CC2_est',
#  'MOVIE3_CC2_val',
#  'MOVIE4_HO2',
#  'MOVIE4_HO2_est',
#  'MOVIE4_HO2_val',
#  'synsets']

# %% [markdown]
# #### So these are organized as TRs x labels

# %%
dset = f["MOVIE1_CC1"]
print(dset.shape)
print(dset.dtype)
# Out:
# (921, 859)
# int8

# %%
labels = f["synsets"]
len(labels)
# Out:
# 859

# %% [markdown]
# #### What are the most common features?

# %%
run_name = "MOVIE1_CC1"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
mean_features = dset.value[np.where(movie_trs)].mean(axis=0)
labels.value[mean_features.argsort()[::-1]][:20]
# Out:
# (921, 859)
# (921,)
# array([b'entity.n.01', b'physical_entity.n.01', b'object.n.01',
#        b'whole.n.02', b'artifact.n.01', b'living_thing.n.01',
#        b'causal_agent.n.01', b'person.n.01', b'adult.n.01',
#        b'abstraction.n.06', b'male.n.02', b'instrumentality.n.03',
#        b'man.n.01', b'matter.n.03', b'structure.n.01', b'thing.n.12',
#        b'fluid.n.02', b'gas.n.02', b'body_part.n.01',
#        b'external_body_part.n.01'], dtype='|S32')

# %%
run_name = "MOVIE2_HO1"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
mean_features = dset.value[np.where(movie_trs)].mean(axis=0)
labels.value[mean_features.argsort()[::-1]][:20]
# Out:
# (918, 859)
# (918,)
# array([b'physical_entity.n.01', b'entity.n.01', b'object.n.01',
#        b'whole.n.02', b'artifact.n.01', b'causal_agent.n.01',
#        b'living_thing.n.01', b'person.n.01', b'adult.n.01',
#        b'structure.n.01', b'man.n.01', b'male.n.02',
#        b'instrumentality.n.03', b'abstraction.n.06', b'act.v.01',
#        b'look.v.01', b'talk.v.02', b'rest.v.01', b'stand.v.01',
#        b'be.v.01'], dtype='|S32')

# %%
run_name = "MOVIE3_CC2"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
mean_features = dset.value[np.where(movie_trs)].mean(axis=0)
labels.value[mean_features.argsort()[::-1]][:20]
# Out:
# (915, 859)
# (915,)
# array([b'entity.n.01', b'physical_entity.n.01', b'object.n.01',
#        b'whole.n.02', b'artifact.n.01', b'living_thing.n.01',
#        b'instrumentality.n.03', b'structure.n.01', b'abstraction.n.06',
#        b'causal_agent.n.01', b'person.n.01', b'plant.n.02', b'adult.n.01',
#        b'container.n.01', b'vascular_plant.n.01', b'group.n.01',
#        b'matter.n.03', b'female.n.02', b'woman.n.01', b'collection.n.01'],
#       dtype='|S32')

# %%
run_name = "MOVIE4_HO2"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
mean_features = dset.value[np.where(movie_trs)].mean(axis=0)
labels.value[mean_features.argsort()[::-1]][:20]
# Out:
# (901, 859)
# (901,)
# array([b'entity.n.01', b'object.n.01', b'physical_entity.n.01',
#        b'whole.n.02', b'artifact.n.01', b'living_thing.n.01',
#        b'causal_agent.n.01', b'person.n.01', b'structure.n.01',
#        b'male.n.02', b'adult.n.01', b'instrumentality.n.03', b'look.v.01',
#        b'travel.v.01', b'female.n.02', b'woman.n.01', b'act.v.01',
#        b'talk.v.02', b'man.n.01', b'be.v.01'], dtype='|S32')

# %% [markdown]
# #### How about in individual clips?

# %%
run_name = "MOVIE1_CC1"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
clipwise_trs = [[i for i,value in it] for key,it in itertools.groupby(enumerate(movie_trs), key=operator.itemgetter(1)) if key != 0]
print(len(clipwise_trs))

n_trs = 143

for clip in range(len(clipwise_trs)):
    print(dset.value[clipwise_trs[clip][:143]].shape)
    mean_features = dset.value[clipwise_trs[clip][:143]].mean(axis=0)
    print(labels.value[mean_features.argsort()[::-1]][:20])
# Out:
# (921, 859)
# (921,)
# 5
# (143, 859)
# [b'object.n.01' b'entity.n.01' b'physical_entity.n.01' b'whole.n.02'
#  b'living_thing.n.01' b'adult.n.01' b'person.n.01' b'male.n.02'
#  b'causal_agent.n.01' b'man.n.01' b'artifact.n.01' b'abstraction.n.06'
#  b'matter.n.03' b'travel.v.01' b'fluid.n.02' b'gas.n.02'
#  b'instrumentality.n.03' b'collection.n.01' b'travel_rapidly.v.01'
#  b'vegetation.n.01']
# (143, 859)
# [b'physical_entity.n.01' b'object.n.01' b'whole.n.02' b'entity.n.01'
#  b'artifact.n.01' b'living_thing.n.01' b'instrumentality.n.03'
#  b'causal_agent.n.01' b'person.n.01' b'structure.n.01' b'adult.n.01'
#  b'male.n.02' b'plant.n.02' b'woody_plant.n.01' b'tree.n.01'
#  b'vascular_plant.n.01' b'matter.n.03' b'gas.n.02' b'man.n.01'
#  b'fluid.n.02']
# (143, 859)
# [b'entity.n.01' b'physical_entity.n.01' b'object.n.01' b'whole.n.02'
#  b'part.n.03' b'thing.n.12' b'body_part.n.01' b'external_body_part.n.01'
#  b'artifact.n.01' b'hold.v.02' b'extremity.n.05' b'hand.n.01'
#  b'living_thing.n.01' b'causal_agent.n.01' b'person.n.01'
#  b'abstraction.n.06' b'instrumentality.n.03' b'adult.n.01' b'male.n.02'
#  b'rest.v.01']
# (58, 859)
# [b'entity.n.01' b'physical_entity.n.01' b'object.n.01' b'person.n.01'
#  b'living_thing.n.01' b'whole.n.02' b'causal_agent.n.01'
#  b'abstraction.n.06' b'matter.n.03' b'artifact.n.01' b'travel.v.01'
#  b'fluid.n.02' b'contestant.n.01' b'geological_formation.n.01'
#  b'thing.n.12' b'gas.n.02' b'relation.n.01' b'part.n.01' b'male.n.02'
#  b'surface.n.01']
# (77, 859)
# [b'object.n.01' b'entity.n.01' b'physical_entity.n.01' b'whole.n.02'
#  b'artifact.n.01' b'instrumentality.n.03' b'thing.n.12'
#  b'abstraction.n.06' b'causal_agent.n.01' b'person.n.01'
#  b'living_thing.n.01' b'device.n.01' b'structure.n.01' b'adult.n.01'
#  b'matter.n.03' b'body_part.n.01' b'external_body_part.n.01' b'part.n.03'
#  b'group.n.01' b'man.n.01']

# %%
run_name = "MOVIE2_HO1"
dset = f[run_name]
print(dset.shape)
movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
print(movie_trs.shape)
clipwise_trs = [[i for i,value in it] for key,it in itertools.groupby(enumerate(movie_trs), key=operator.itemgetter(1)) if key != 0]
print(len(clipwise_trs))

n_trs = 143

for clip in range(len(clipwise_trs)):
    print(dset.value[clipwise_trs[clip][:143]].shape)
    mean_features = dset.value[clipwise_trs[clip][:143]].mean(axis=0)
    print(labels.value[mean_features.argsort()[::-1]][:20])
# Out:
# (918, 859)
# (918,)
# 4
# (143, 859)
# [b'object.n.01' b'artifact.n.01' b'physical_entity.n.01' b'whole.n.02'
#  b'entity.n.01' b'way.n.06' b'structure.n.01' b'building.n.01'
#  b'living_thing.n.01' b'person.n.01' b'adult.n.01' b'causal_agent.n.01'
#  b'abstraction.n.06' b'female.n.02' b'woman.n.01' b'man.n.01' b'male.n.02'
#  b'road.n.01' b'instrumentality.n.03' b'travel.v.01']
# (143, 859)
# [b'entity.n.01' b'object.n.01' b'whole.n.02' b'physical_entity.n.01'
#  b'artifact.n.01' b'living_thing.n.01' b'causal_agent.n.01' b'person.n.01'
#  b'instrumentality.n.03' b'structure.n.01' b'act.v.01' b'talk.v.02'
#  b'adult.n.01' b'male.n.02' b'man.n.01' b'sit.v.01' b'room.n.01'
#  b'area.n.05' b'furnishing.n.02' b'table.n.02']
# (143, 859)
# [b'entity.n.01' b'object.n.01' b'male.n.02' b'adult.n.01' b'person.n.01'
#  b'physical_entity.n.01' b'artifact.n.01' b'causal_agent.n.01' b'man.n.01'
#  b'whole.n.02' b'living_thing.n.01' b'structure.n.01'
#  b'instrumentality.n.03' b'rest.v.01' b'be.v.01' b'stand.v.01' b'act.v.01'
#  b'talk.v.02' b'device.n.01' b'look.v.01']
# (77, 859)
# [b'object.n.01' b'entity.n.01' b'physical_entity.n.01' b'whole.n.02'
#  b'artifact.n.01' b'instrumentality.n.03' b'thing.n.12'
#  b'abstraction.n.06' b'causal_agent.n.01' b'person.n.01'
#  b'living_thing.n.01' b'device.n.01' b'structure.n.01' b'adult.n.01'
#  b'matter.n.03' b'body_part.n.01' b'external_body_part.n.01' b'part.n.03'
#  b'group.n.01' b'man.n.01']

# %%
n_clips = len(video_tr_lookup["clip_name"])
n_features = len(labels)

df = pd.DataFrame(np.zeros((n_clips, n_features)), index=video_tr_lookup["clip_name"])
df.shape
# Out:
# (18, 859)

# %%
n_clips = len(video_tr_lookup["clip_name"])
n_features = len(labels)

df = pd.DataFrame(np.zeros((n_clips, n_features)), index=video_tr_lookup["clip_name"], columns=labels)

for run_name in ["MOVIE1_CC1", "MOVIE2_HO1", "MOVIE3_CC2", "MOVIE4_HO2"]:
    run_short_name = run_name.split('_')[0]
    
    dset = f[run_name]
    movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
    clipwise_trs = [[i for i,value in it] for key,it in itertools.groupby(enumerate(movie_trs), key=operator.itemgetter(1)) if key != 0]
    
    n_trs = 143

    for clip_no in range(len(clipwise_trs)):
        clip_name = video_tr_lookup[(video_tr_lookup["run"].str.contains(run_short_name)) & (video_tr_lookup["clipno_in_run"]==clip_no+1)]["clip_name"]
        print(dset.value[clipwise_trs[clip_no][:143]].shape)
        mean_features = dset.value[clipwise_trs[clip_no][:143]].mean(axis=0)
        df.loc[clip_name,:] = mean_features
# Out:
# (143, 859)
# (143, 859)
# (143, 859)
# (58, 859)
# (77, 859)
# (143, 859)
# (143, 859)
# (143, 859)
# (77, 859)
# (143, 859)
# (143, 859)
# (143, 859)
# (136, 859)
# (77, 859)
# (143, 859)
# (143, 859)
# (143, 859)
# (77, 859)

# %%
df
# Out:
# /synsets     b'abdomen.n.01'  b'abstraction.n.06'  b'accept.v.01'  \
# clip_name
# twomen              0.000000             0.762238        0.000000
# bridgeville         0.000000             0.356643        0.000000
# pockets             0.000000             0.405594        0.000000
# overcome            0.000000             0.620690        0.000000
# testretest1         0.051948             0.545455        0.000000
# inception           0.000000             0.881119        0.000000
# socialnet           0.000000             0.412587        0.000000
# oceans              0.000000             0.622378        0.000000
# testretest2         0.051948             0.545455        0.000000
# flower              0.000000             0.622378        0.000000
# hotel               0.000000             0.048951        0.000000
# garden              0.000000             0.384615        0.000000
# dreary              0.000000             0.889706        0.000000
# testretest3         0.051948             0.545455        0.000000
# homealone           0.000000             0.188811        0.000000
# brokovich           0.000000             0.384615        0.020979
# starwars            0.000000             0.293706        0.000000
# testretest4         0.051948             0.545455        0.000000
#
# /synsets     b'access.n.03'  b'act.n.02'  b'act.v.01'  b'act.v.02'  \
# clip_name
# twomen             0.000000     0.000000     0.013986     0.000000
# bridgeville        0.000000     0.062937     0.293706     0.000000
# pockets            0.000000     0.034965     0.230769     0.027972
# overcome           0.000000     0.051724     0.086207     0.000000
# testretest1        0.000000     0.051948     0.077922     0.000000
# inception          0.000000     0.034965     0.398601     0.000000
# socialnet          0.000000     0.000000     0.762238     0.000000
# oceans             0.000000     0.104895     0.755245     0.006993
# testretest2        0.000000     0.051948     0.077922     0.000000
# flower             0.000000     0.000000     0.006993     0.013986
# hotel              0.000000     0.006993     0.000000     0.097902
# garden             0.000000     0.027972     0.223776     0.000000
# dreary             0.000000     0.000000     0.000000     0.000000
# testretest3        0.000000     0.051948     0.077922     0.000000
# homealone          0.000000     0.000000     0.468531     0.034965
# brokovich          0.013986     0.000000     0.468531     0.013986
# starwars           0.013986     0.000000     0.195804     0.006993
# testretest4        0.000000     0.051948     0.077922     0.000000
#
# /synsets     b'act.v.08'  b'actinic_radiation.n.01'  b'action.n.01'  ...  \
# clip_name                                                            ...
# twomen          0.000000                   0.000000        0.000000  ...
# bridgeville     0.000000                   0.000000        0.000000  ...
# pockets         0.000000                   0.000000        0.034965  ...
# overcome        0.051724                   0.068966        0.051724  ...
# testretest1     0.000000                   0.000000        0.000000  ...
# inception       0.000000                   0.000000        0.034965  ...
# socialnet       0.000000                   0.000000        0.000000  ...
# oceans          0.000000                   0.000000        0.000000  ...
# testretest2     0.000000                   0.000000        0.000000  ...
# flower          0.000000                   0.000000        0.000000  ...
# hotel           0.000000                   0.000000        0.006993  ...
# garden          0.000000                   0.000000        0.000000  ...
# dreary          0.000000                   0.000000        0.000000  ...
# testretest3     0.000000                   0.000000        0.000000  ...
# homealone       0.000000                   0.000000        0.000000  ...
# brokovich       0.006993                   0.000000        0.000000  ...
# starwars        0.000000                   0.000000        0.000000  ...
# testretest4     0.000000                   0.000000        0.000000  ...
#
# /synsets     b'work.n.02'  b'work.v.01'  b'work.v.02'  b'work_surface.n.01'  \
# clip_name
# twomen           0.000000      0.000000      0.000000              0.000000
# bridgeville      0.000000      0.000000      0.000000              0.000000
# pockets          0.104895      0.000000      0.000000              0.000000
# overcome         0.000000      0.000000      0.000000              0.000000
# testretest1      0.025974      0.000000      0.000000              0.000000
# inception        0.000000      0.000000      0.000000              0.000000
# socialnet        0.000000      0.000000      0.000000              0.000000
# oceans           0.000000      0.000000      0.000000              0.000000
# testretest2      0.025974      0.000000      0.000000              0.000000
# flower           0.000000      0.000000      0.000000              0.111888
# hotel            0.000000      0.000000      0.000000              0.000000
# garden           0.000000      0.000000      0.000000              0.000000
# dreary           0.000000      0.000000      0.000000              0.000000
# testretest3      0.025974      0.000000      0.000000              0.000000
# homealone        0.000000      0.000000      0.000000              0.000000
# brokovich        0.000000      0.000000      0.000000              0.000000
# starwars         0.000000      0.125874      0.097902              0.000000
# testretest4      0.025974      0.000000      0.000000              0.000000
#
# /synsets     b'worker.n.01'  b'worsen.v.02'  b'wristband.n.01'  b'write.v.02'  \
# clip_name
# twomen             0.000000        0.000000           0.000000       0.000000
# bridgeville        0.000000        0.000000           0.000000       0.000000
# pockets            0.000000        0.000000           0.020979       0.000000
# overcome           0.000000        0.000000           0.000000       0.000000
# testretest1        0.000000        0.000000           0.012987       0.025974
# inception          0.000000        0.000000           0.000000       0.000000
# socialnet          0.251748        0.000000           0.000000       0.041958
# oceans             0.000000        0.000000           0.000000       0.000000
# testretest2        0.000000        0.000000           0.012987       0.025974
# flower             0.000000        0.000000           0.000000       0.000000
# hotel              0.000000        0.000000           0.000000       0.000000
# garden             0.000000        0.000000           0.000000       0.000000
# dreary             0.000000        0.000000           0.000000       0.000000
# testretest3        0.000000        0.000000           0.012987       0.025974
# homealone          0.076923        0.000000           0.000000       0.000000
# brokovich          0.000000        0.027972           0.000000       0.000000
# starwars           0.083916        0.000000           0.000000       0.000000
# testretest4        0.000000        0.000000           0.012987       0.025974
#
# /synsets     b'written_communication.n.01'  b'written_record.n.01'
# clip_name
# twomen                            0.412587                0.412587
# bridgeville                       0.083916                0.000000
# pockets                           0.097902                0.000000
# overcome                          0.068966                0.000000
# testretest1                       0.207792                0.000000
# inception                         0.000000                0.000000
# socialnet                         0.000000                0.000000
# oceans                            0.000000                0.000000
# testretest2                       0.207792                0.000000
# flower                            0.013986                0.000000
# hotel                             0.013986                0.000000
# garden                            0.258741                0.000000
# dreary                            0.000000                0.000000
# testretest3                       0.207792                0.000000
# homealone                         0.000000                0.000000
# brokovich                         0.000000                0.000000
# starwars                          0.000000                0.000000
# testretest4                       0.207792                0.000000
#
# [18 rows x 859 columns]

# %%
cogn_median_vals = pd.read_csv('cogn_median_val_trs-143.csv', index_col="clip")
cogn_median_vals
# Out:
#                 r_val
# clip
# oceans       0.342261
# dreary       0.040545
# garden       0.182495
# hotel        0.141923
# inception    0.222143
# brokovich    0.187331
# starwars     0.211377
# twomen       0.180369
# pockets      0.216468
# homealone    0.198027
# socialnet    0.379092
# bridgeville  0.120825
# flower       0.051353

# %%
df = df.reindex(index=cogn_median_vals.index)
df.head()
# Out:
# /synsets   b'abdomen.n.01'  b'abstraction.n.06'  b'accept.v.01'  \
# clip
# oceans                 0.0             0.622378             0.0
# dreary                 0.0             0.889706             0.0
# garden                 0.0             0.384615             0.0
# hotel                  0.0             0.048951             0.0
# inception              0.0             0.881119             0.0
#
# /synsets   b'access.n.03'  b'act.n.02'  b'act.v.01'  b'act.v.02'  b'act.v.08'  \
# clip
# oceans                0.0     0.104895     0.755245     0.006993          0.0
# dreary                0.0     0.000000     0.000000     0.000000          0.0
# garden                0.0     0.027972     0.223776     0.000000          0.0
# hotel                 0.0     0.006993     0.000000     0.097902          0.0
# inception             0.0     0.034965     0.398601     0.000000          0.0
#
# /synsets   b'actinic_radiation.n.01'  b'action.n.01'  ...  b'work.n.02'  \
# clip                                                  ...
# oceans                           0.0        0.000000  ...           0.0
# dreary                           0.0        0.000000  ...           0.0
# garden                           0.0        0.000000  ...           0.0
# hotel                            0.0        0.006993  ...           0.0
# inception                        0.0        0.034965  ...           0.0
#
# /synsets   b'work.v.01'  b'work.v.02'  b'work_surface.n.01'  b'worker.n.01'  \
# clip
# oceans              0.0           0.0                   0.0             0.0
# dreary              0.0           0.0                   0.0             0.0
# garden              0.0           0.0                   0.0             0.0
# hotel               0.0           0.0                   0.0             0.0
# inception           0.0           0.0                   0.0             0.0
#
# /synsets   b'worsen.v.02'  b'wristband.n.01'  b'write.v.02'  \
# clip
# oceans                0.0                0.0            0.0
# dreary                0.0                0.0            0.0
# garden                0.0                0.0            0.0
# hotel                 0.0                0.0            0.0
# inception             0.0                0.0            0.0
#
# /synsets   b'written_communication.n.01'  b'written_record.n.01'
# clip
# oceans                          0.000000                     0.0
# dreary                          0.000000                     0.0
# garden                          0.258741                     0.0
# hotel                           0.013986                     0.0
# inception                       0.000000                     0.0
#
# [5 rows x 859 columns]

# %%
X = df[cogn_median_vals.notna().values]
Y = cogn_median_vals[cogn_median_vals.notna().values]

pls = PLSRegression(n_components=2)
pls.fit(X, Y)
# Out:
# PLSRegression(copy=True, max_iter=500, n_components=2, scale=True, tol=1e-06)

# %%
from sklearn.metrics import r2_score

r2_sum = 0
for i in range(0,2):
        Y_pred=np.dot(pls.x_scores_[:,i].reshape(-1,1),pls.y_loadings_[:,i].reshape(-1,1).T)*Y.std(axis=0, ddof=1)[0]+Y.mean(axis=0)[0]
        r2_sum += round(r2_score(Y,Y_pred),3) 
        print('R2 for %d component: %g' %(i+1,round(r2_score(Y,Y_pred),3)))
print('R2 for all components (): %g' %r2_sum) #Sum of above
print('R2 for all components (): %g' %round(r2_score(Y,pls.predict(X)),3)) #Calcuted from PLSRegression's 'predict' function.
# Out:
# R2 for 1 component: 0.962
# R2 for 2 component: 0.035
# R2 for all components (): 0.997
# R2 for all components (): 0.997

# %%
pls.coef_.shape
# Out:
# (859, 1)

# %%
print("Highest loadings:")
print(labels.value[pls.x_loadings_[:,0].argsort()[::-1][:15]])

print("Lowest loadings:")
print(labels.value[pls.x_loadings_[:,0].argsort()[:15]])
# Out:
# Highest loadings:
# [b'act.v.01' b'talk.v.02' b'partition.n.01' b'substance.n.07'
#  b'causal_agent.n.01' b'person.n.01' b'physical_entity.n.01' b'male.n.02'
#  b'sit.v.01' b'look.v.01' b'man.n.01' b'consume.v.02' b'spectacles.n.01'
#  b'change_posture.v.01' b'adult.n.01']
# Lowest loadings:
# [b'mammal.n.01' b'telephone_pole.n.01' b'post.n.04' b'sign.n.02'
#  b'building_material.n.01' b'collection.n.01' b'vegetation.n.01'
#  b'outbuilding.n.01' b'support.n.10' b'atmospheric_phenomenon.n.01'
#  b'chordate.n.01' b'phenomenon.n.01' b'helmet.n.02'
#  b'structural_member.n.01' b'upright.n.01']

# %%
fig, ax = plt.subplots(1,2, sharey=True)

ax[0].plot(np.sort(pls.x_loadings_[:,0]))
ax[0].set_title("Component 1")

ax[1].plot(np.sort(pls.x_loadings_[:,1]))
ax[1].set_title("Component 2")
# Out:
# Text(0.5, 1.0, 'Component 2')

# %%
x = pls.y_scores_[:,0]
y = pls.y_scores_[:,1]

fig, ax = plt.subplots()
ax.scatter(x, y)
annotations = [ax.annotate(txt, (x[i], y[i])) for i,txt in enumerate(X.index)]
ax.set_xlabel("PLSR Comp. 1")
ax.set_ylabel("PLSR Comp. 2")
# Out:
# Text(0, 0.5, 'PLSR Comp. 2')

# %%
n_features = 10
fig, ax = plt.subplots(figsize=(8,10))

cmp = 0

sns.set(font_scale=2)
    
weights = pls.x_loadings_[:,cmp]

labeled_weights = tuple(zip(labels, weights))
labeled_weights = sorted(labeled_weights, key=lambda x: x[1])

vmin = np.min([x[1] for x in labeled_weights])
vmax = np.max([x[1] for x in labeled_weights])
cmap='RdBu_r'

# Do high
high_data = [x[1] for x in labeled_weights[-n_features:]][::-1]
high_annots = [x[0].decode('utf-8') for x in labeled_weights[-n_features:]][::-1]

# Do low
low_data = [x[1] for x in labeled_weights[:n_features]][::-1]
low_annots = [x[0].decode('utf-8') for x in labeled_weights[:n_features]][::-1]

sns.heatmap(np.atleast_2d(high_data+low_data).T, ax=ax, 
            annot=np.atleast_2d(high_annots+low_annots).T, fmt='s',
           cmap=cmap, vmin=vmin, vmax=vmax, center=0
           )

plt.axis('off')
# Out:
# (0.0, 1.0, 20.0, 0.0)

# %%
n_features = 10
fig, axes = plt.subplots(2,1,figsize=(6,10))

cmp = 0

sns.set(font_scale=2)
    
weights = pls.x_loadings_[:,cmp]

labeled_weights = tuple(zip(labels, weights))
labeled_weights = sorted(labeled_weights, key=lambda x: x[1])

vmin = np.min([x[1] for x in labeled_weights])
vmax = np.max(abs(np.array([x[1] for x in labeled_weights])))
# vmin = -vmax
print(np.min([x[1] for x in labeled_weights]))
print(vmax)
cmap='RdBu_r'

# Do high
high_data = [x[1] for x in labeled_weights[-n_features:]][::-1]
high_annots = [x[0].decode('utf-8') for x in labeled_weights[-n_features:]][::-1]

sns.heatmap(np.atleast_2d(high_data).T,
            annot=np.atleast_2d(high_annots).T, fmt='s',
           cmap=cmap, vmin=0, vmax=vmax,
            ax=axes[0],
            cbar=False
           )

axes[0].axis('off')

# Do low
low_data = [x[1] for x in labeled_weights[:n_features]][::-1]
low_annots = [x[0].decode('utf-8') for x in labeled_weights[:n_features]][::-1]

sns.heatmap(np.atleast_2d(low_data).T,
            annot=np.atleast_2d(low_annots).T, fmt='s',
           cmap=cmap, vmin=vmin, vmax=0,
            ax=axes[1],
            cbar=False
           )

plt.axis('off')
# Out:
# -0.08700274202059285
# 0.11379386178134958
# (0.0, 1.0, 10.0, 0.0)

# %%
fig, ax = plt.subplots(figsize=(0.5,10))

# my_cmap = mpl.cm.ScalarMappable(norm=mpl.colors.Normalize(vmin=vmin, vmax=vmax), cmap=mpl.cm.RdBu_r)

cbar = mpl.colorbar.ColorbarBase(ax, cmap=mpl.cm.RdBu_r, norm=mpl.colors.Normalize(vmin=vmin, vmax=vmax))
# cbar.set_ticks(np.arange(-0.08, 0.05, 0.1))

# my_cmap.set_clim(-0.08, 0.1)
# cbar = mpl.colorbar.Colorbar(ax, my_cmap)
# cbar.set_clim(-0.08, 0.1)

# %% [markdown]
# ### Using linear regression

# %%
print(X.shape)
print(Y.shape)

reg = LinearRegression(fit_intercept=False, normalize=True)
reg.fit(X,Y)

n_features = 10

weights = reg.coef_.flatten().T

labeled_weights = tuple(zip(labels, weights))
labeled_weights = sorted(labeled_weights, key=lambda x: x[1])

fig, ax = plt.subplots(figsize=(3,10))

vmin = np.min([x[1] for x in labeled_weights])
vmax = np.max([x[1] for x in labeled_weights])
cmap='RdBu_r'

# Do high
high_data = [x[1] for x in labeled_weights[-n_features:]][::-1]
high_annots = [x[0] for x in labeled_weights[-n_features:]][::-1]

# Do low
low_data = [x[1] for x in labeled_weights[:n_features]][::-1]
low_annots = [x[0] for x in labeled_weights[:n_features]][::-1]

sns.heatmap(np.atleast_2d(high_data+low_data).T, ax=ax, 
            annot=np.atleast_2d(high_annots+low_annots).T, fmt='s',
           cmap=cmap, vmin=vmin, vmax=vmax
           )
# Out:
# (13, 859)
# (13, 1)

# %%
reg.singular_
# Out:
# array([11.6326266 ,  3.20946487,  2.95905438,  2.26261694,  2.21814756,
#         2.12756136,  2.01453902,  1.83516505,  1.73141283,  1.58561287,
#         1.34528651,  1.23360108,  1.04373083])

# %%
Y-reg.predict(X)
# Out:
#                     r_val
# clip
# oceans       3.330669e-16
# dreary      -2.428613e-16
# garden       3.608225e-16
# hotel        2.498002e-16
# inception    3.330669e-16
# brokovich    3.608225e-16
# starwars     1.110223e-16
# twomen       5.551115e-16
# pockets      1.110223e-16
# homealone    3.053113e-16
# socialnet    4.996004e-16
# bridgeville  2.498002e-16
# flower       3.330669e-16

# %%
plt.scatter(Y, reg.predict(X))

# %% [markdown]
# ## Look at Pliers-based features

# %%
cogn_median_vals = pd.read_csv('cogn_median_val_trs-143.csv', index_col="clip")
cogn_median_vals
# Out:
#                 r_val
# clip
# oceans       0.342261
# dreary       0.040545
# garden       0.182495
# hotel        0.141923
# inception    0.222143
# brokovich    0.187331
# starwars     0.211377
# twomen       0.180369
# pockets      0.216468
# homealone    0.198027
# socialnet    0.379092
# bridgeville  0.120825
# flower       0.051353

# %%
clip_list = cogn_median_vals.index

features = [('Brightness', 'brightness'),
#             ('Vibrance', 'vibrance'),
            ('Optflow', 'total_flow'),
            ('RMS', 'rms')]

stats = ["mean", 
         # "median",
         "std"]

result = pd.DataFrame(index=clip_list, columns = [x[0]+'_'+y for x in features for y in stats])

# %%
n_trs = 143
start_tr_pad = 10

for clip in clip_list:
    print(clip)
    run = video_tr_lookup.query('clip_name==@clip')["run"].tolist()[0] # figure out which run this clip is in
    run = run.split('_')[0]
    start_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "start_tr"].values[0]+start_tr_pad
    if n_trs is None:
        end_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "stop_tr"].values[0]
    elif n_trs is not None:
        end_tr = start_tr + n_trs 
    # print("start, stop trs: {},{}".format(start_tr, end_tr))
 
    for feature, feat_col in features:
        f_name = glob.glob('./7T_movie_stimulus/feature_extraction/' + feature + 'Extractor_7T_' + run + '*.csv')[0]
        data = pd.read_csv(f_name)
        # print("f_name: {}".format(f_name))

        tr_idx = (data["onset"]>start_tr) & (data["onset"]<end_tr)

        result.loc[clip, feature+"_mean"] = np.mean(data[feat_col][tr_idx])
        # result.loc[clip, feature+"_median"] = np.median(data[feat_col][tr_idx])
        result.loc[clip, feature+"_std"] = np.std(data[feat_col][tr_idx])
# Out:
# oceans
# dreary
# garden
# hotel
# inception
# brokovich
# starwars
# twomen
# pockets
# homealone
# socialnet
# bridgeville
# flower

# %%
result
# Out:
#             Brightness_mean Brightness_std Optflow_mean  Optflow_std  \
# clip
# oceans             0.194174      0.0450095       308742       597097
# dreary             0.345002       0.180715       461704       744793
# garden             0.501991       0.118884  1.93431e+06   2.1952e+06
# hotel              0.441508       0.111025       310332       435640
# inception          0.224016      0.0425352  1.94851e+06  1.22648e+06
# brokovich           0.50126       0.109313  2.33156e+06  2.35933e+06
# starwars            0.48454       0.123043  1.45776e+06  1.43572e+06
# twomen             0.355873       0.102981  1.17398e+06  2.04192e+06
# pockets            0.535599      0.0778494       379944       481523
# homealone          0.232775      0.0584691       659901       834770
# socialnet          0.144997      0.0402476       417812       658811
# bridgeville         0.44803       0.115586       509125  1.25445e+06
# flower             0.498981       0.199109  1.68364e+06   2.2047e+06
#
#                RMS_mean     RMS_std
# clip
# oceans       0.00952785  0.00996102
# dreary       0.00611669  0.00372078
# garden        0.0220961   0.0117548
# hotel        0.00236509  0.00425779
# inception     0.0281695   0.0305206
# brokovich     0.0108872  0.00953885
# starwars      0.0192851   0.0164125
# twomen        0.0214162   0.0184442
# pockets       0.0160316  0.00540246
# homealone    0.00638985   0.0116077
# socialnet     0.0068364  0.00560713
# bridgeville   0.0216791   0.0133741
# flower        0.0344292   0.0147239

# %%
fig, axes = plt.subplots(4,2, figsize=(10,10))

for s,stat in enumerate(result.columns):
    ax = axes.flatten()[s]
    x = result[stat].astype(float)
    y = cogn_median_vals.astype(float)
    r = sp.stats.pearsonr(x.values,y.values.squeeze())[0]
    r = "{:.2f}".format(r)
    sns.regplot(x=x, y=y, ax=ax)
    ax.annotate(r, xy=(0.1, 0.9), xycoords='axes fraction')

fig.tight_layout()

# %%
fig, axes = plt.subplots(3,2, figsize=(10,15), sharey=True)

cols_of_interest = ["Brightness_mean", "Brightness_std", "Optflow_mean", "Optflow_std", "RMS_mean", "RMS_std"]
clips_to_highlight = {"oceans": "crimson",
                      "socialnet": "orangered",
                      "flower": "royalblue",
                      "dreary": "skyblue"}

plt.rcParams.update({'font.size': 22})
sns.set_style('white')

for s,stat in enumerate(result[cols_of_interest]):
    ax = axes.flatten()[s]
    x = result[stat].astype(float)
    y = cogn_median_vals.astype(float)
    
    # if stat =="Brightness_std":
    #    color = [clips_to_highlight[clip] if clip in clips_to_highlight.keys() else 'black' for clip in x.index]
    # else:
    #    color = 'black'
    
    r,p = sp.stats.pearsonr(x.values,y.values.squeeze())
    r = "{:.2f}".format(r)
    
    # Do Bonferroni correction
    p = p*len(cols_of_interest)
    if p < 0.05:
        color='black'
    else:
        color='darkgray'
        
    ax.scatter(x,y,color=color)
    sns.regplot(x=x, y=y, ax=ax, color=color, scatter=False) # use Seaborn to get the line of best fit, but not the points
    ax.annotate(f"r = {r}", xy=(0.65, 0.9), xycoords='axes fraction', color=color)
    print(stat, p)
    
    ax.set_xlabel('')
    
    if s==0:
        ax.set_ylabel("Cogn r(obs,pred)")
        ax.set_title('Mean across frames')
        
        ymin = ax.get_position().ymin
        plt.figtext(0.5, ymin-0.02, "Brightness", ha='center', fontsize=22)    
    elif s==1:
        ax.set_title('St. dev. across frames')
        ax.yaxis.set_visible(False)
    else:
        ax.yaxis.set_visible(False)
        
    pad = plt.rcParams["xtick.major.size"] + plt.rcParams["xtick.major.pad"]
    def bottom_offset(self, bboxes, bboxes2):
        bottom = self.axes.bbox.ymin
        self.offsetText.set(va="top", ha="left") 
        oy = bottom - pad * self.figure.dpi / 72.0
        self.offsetText.set_position((0.9, oy))
        
    if s==2 or s==3:
        ax.ticklabel_format(axis='x', style='sci', scilimits=(10,10000))
        ax.xaxis._update_offset_text_position = types.MethodType(bottom_offset, ax.xaxis)

    
    if s==2:
        ymin = ax.get_position().ymin
        plt.figtext(0.5, ymin-0.05, "Optical flow", ha='center', fontsize=22)   
        
    if s==4:
        ymin = ax.get_position().ymin
        plt.figtext(0.5, ymin-0.05, "Audio RMS", ha='center', fontsize=22)    

    plt.subplots_adjust(hspace=0.5)



# fig.tight_layout()
# Out:
# Brightness_mean 0.20680065049836327
# Brightness_std 0.0007664711933034438
# Optflow_mean 3.3207382069907205
# Optflow_std 1.670554261025945
# RMS_mean 2.0130361365585765
# RMS_std 5.85904037872622

# %%
clip_list1 = [("oceans", "crimson"),
              ("socialnet", "orangered")]

clip_list2 = [("flower", "royalblue"),
               ("dreary", "skyblue")]

feature, feat_col = ('Brightness', 'brightness')
n_trs = 143
start_tr_pad = 10

plt.rcParams.update({'font.size': 22})
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5), sharey=True)
              
for clip, color in clip_list1:
    print(clip)
    run = video_tr_lookup.query('clip_name==@clip')["run"].tolist()[0] # figure out which run this clip is in
    run = run.split('_')[0]
    start_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "start_tr"].values[0]+start_tr_pad
    if n_trs is None:
        end_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "stop_tr"].values[0]
    elif n_trs is not None:
        end_tr = start_tr + n_trs 
        
    f_name = glob.glob('./7T_movie_stimulus/feature_extraction/' + feature + 'Extractor_7T_' + run + '*.csv')[0]
    data = pd.read_csv(f_name)

    tr_idx = (data["onset"]>start_tr) & (data["onset"]<end_tr)
    mean = data[feat_col][tr_idx].mean()
    std = data[feat_col][tr_idx].std()

    ax1.plot(np.arange(0, n_trs, n_trs/data[feat_col][tr_idx].shape[0]), data[feat_col][tr_idx].values, color=color, label=clip)
    ax1.axhline(mean, color=color, linestyle='--')
    # ax1.axhline(mean+std, color=color, linestyle='--')
    # ax1.axhline(mean-std, color=color, linestyle='--')
    ax1.legend()
              
for clip, color in clip_list2:
    print(clip)
    run = video_tr_lookup.query('clip_name==@clip')["run"].tolist()[0] # figure out which run this clip is in
    run = run.split('_')[0]
    start_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "start_tr"].values[0]+start_tr_pad
    if n_trs is None:
        end_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "stop_tr"].values[0]
    elif n_trs is not None:
        end_tr = start_tr + n_trs 
        
    f_name = glob.glob('./7T_movie_stimulus/feature_extraction/' + feature + 'Extractor_7T_' + run + '*.csv')[0]
    data = pd.read_csv(f_name)

    tr_idx = (data["onset"]>start_tr) & (data["onset"]<end_tr)
    mean = data[feat_col][tr_idx].mean()
    std = data[feat_col][tr_idx].std()
    
    ax2.plot(np.arange(0, n_trs, n_trs/data[feat_col][tr_idx].shape[0]), data[feat_col][tr_idx].values, color=color, label=clip)
    ax2.axhline(mean, color=color, linestyle='--')
    # ax2.axhline(mean+std, color=color, linestyle='--')
    # ax2.axhline(mean-std, color=color, linestyle='--')
    ax2.legend()

ax1.set_xlabel('Time (s)')
ax2.set_xlabel('Time (s)')
ax1.set_ylabel(feature)

ax1.set_title('Two best-performing clips')
ax2.set_title('Two worst-performing clips')

fig.tight_layout()
# Out:
# oceans
# socialnet
# flower
# dreary

# %%
clip_list = ['twomen', 'bridgeville', 'pockets',
       'inception', 'socialnet', 'oceans', 
       'flower', 'hotel', 'garden', 'dreary', 
             'homealone','brokovich', 'starwars']

# %%
isc_std = [0.20638583076411696, 0.2472282605377029, 0.2429869679189101,
       0.19130114715513274, 0.27036165181914024, 0.24471736066234023,
       0.18856389757344136, 0.19920753567802188, 0.1569331973936574,
       0.15324843771464164, 0.20742646976850204, 0.265004882782569,
       0.20003272487512733]

# %%
result.loc[clip_list, "Brightness_std"]
# Out:
# clip
# twomen          0.102981
# bridgeville     0.115586
# pockets        0.0778494
# inception      0.0425352
# socialnet      0.0402476
# oceans         0.0450095
# flower          0.199109
# hotel           0.111025
# garden          0.118884
# dreary          0.180715
# homealone      0.0584691
# brokovich       0.109313
# starwars        0.123043
# Name: Brightness_std, dtype: object

# %%
x = result.loc[clip_list, "Brightness_std"]
y = isc_std

plt.scatter(x,y)
plt.xlabel('Brightness_std')
plt.ylabel('Eye-track ISC std')

print(sp.stats.pearsonr(x, y))
print(sp.stats.spearmanr(x, y))
# Out:
# (-0.53456331684126, 0.059823385233894175)
# SpearmanrResult(correlation=-0.5879120879120878, pvalue=0.03458605834210788)

# %% [markdown]
# Does eye-tracking ISC std mediate the effect of Brightness_std on predictive power? Seems like not...

# %%
from pingouin import mediation_analysis

data = pd.DataFrame(index=clip_list, dtype='float')
data["EyeISC_std"] = isc_std
data["Brightness_std"] = result.loc[clip_list, "Brightness_std"].values.astype(float)
data["r"] = cogn_median_vals.loc[clip_list].values.astype(float)

mediation_analysis(data=data, x="Brightness_std", m = "EyeISC_std", y="r")
# Out:
#        Path    Beta  CI[2.5%]  CI[97.5%]  Sig
# 0    X -> M -0.4075   -0.8350     0.0200   No
# 1    M -> Y  1.5278    0.1956     2.8600  Yes
# 2    X -> Y -1.6659   -2.3033    -1.0286  Yes
# 3    Direct -1.4609   -2.2145    -0.7072  Yes
# 4  Indirect -0.2051   -1.0859     0.1145   No

# %% [markdown]
# ### Look at number of faces

# %%
n_trs = 143
start_tr_pad = 10

for clip in clip_list:
    run = video_tr_lookup.query('clip_name==@clip')["run"].tolist()[0] # figure out which run this clip is in
    run = run.split('_')[0]
    start_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "start_tr"].values[0]+start_tr_pad
    if n_trs is None:
        end_tr = video_tr_lookup.loc[video_tr_lookup["clip_name"]==clip, "stop_tr"].values[0]
    elif n_trs is not None:
        end_tr = start_tr + n_trs 
    # print("start, stop trs: {},{}".format(start_tr, end_tr))
 
    for feature, feat_col in features:
        f_name = glob.glob('./7T_movie_stimulus/feature_extraction/FaceExtractor_7T_' + run + '*.csv')[0]
        data = pd.read_csv(f_name)
        # print("f_name: {}".format(f_name))

        time = np.arange(start_tr,end_tr,1)
        n_faces = np.array([t in data["onset"].values for t in time]).sum()

        result.loc[clip, "n_faces"] = n_faces

result
# Out:
#             Brightness_mean Brightness_std Optflow_mean  Optflow_std  \
# clip
# oceans             0.194174      0.0450095       308742       597097
# dreary             0.345002       0.180715       461704       744793
# garden             0.501991       0.118884  1.93431e+06   2.1952e+06
# hotel              0.441508       0.111025       310332       435640
# inception          0.224016      0.0425352  1.94851e+06  1.22648e+06
# brokovich           0.50126       0.109313  2.33156e+06  2.35933e+06
# starwars            0.48454       0.123043  1.45776e+06  1.43572e+06
# twomen             0.355873       0.102981  1.17398e+06  2.04192e+06
# pockets            0.535599      0.0778494       379944       481523
# homealone          0.232775      0.0584691       659901       834770
# socialnet          0.144997      0.0402476       417812       658811
# bridgeville         0.44803       0.115586       509125  1.25445e+06
# flower             0.498981       0.199109  1.68364e+06   2.2047e+06
#
#                RMS_mean     RMS_std  n_faces
# clip
# oceans       0.00952785  0.00996102     84.0
# dreary       0.00611669  0.00372078      0.0
# garden        0.0220961   0.0117548     28.0
# hotel        0.00236509  0.00425779     25.0
# inception     0.0281695   0.0305206     84.0
# brokovich     0.0108872  0.00953885     49.0
# starwars      0.0192851   0.0164125     10.0
# twomen        0.0214162   0.0184442     25.0
# pockets       0.0160316  0.00540246     36.0
# homealone    0.00638985   0.0116077     21.0
# socialnet     0.0068364  0.00560713    106.0
# bridgeville   0.0216791   0.0133741     69.0
# flower        0.0344292   0.0147239      1.0

# %%
rename_dict = {
    "twomen": "two men",
    "oceans": "ocean's 11",
    "socialnet": "social net",
    "homealone": "home alone",
    "starwars": "star wars"
}

result = result.rename(index=rename_dict)
result
# Out:
#             Brightness_mean Brightness_std Optflow_mean  Optflow_std  \
# clip
# ocean's 11         0.194174      0.0450095       308742       597097
# dreary             0.345002       0.180715       461704       744793
# garden             0.501991       0.118884  1.93431e+06   2.1952e+06
# hotel              0.441508       0.111025       310332       435640
# inception          0.224016      0.0425352  1.94851e+06  1.22648e+06
# brokovich           0.50126       0.109313  2.33156e+06  2.35933e+06
# star wars           0.48454       0.123043  1.45776e+06  1.43572e+06
# two men            0.355873       0.102981  1.17398e+06  2.04192e+06
# pockets            0.535599      0.0778494       379944       481523
# home alone         0.232775      0.0584691       659901       834770
# social net         0.144997      0.0402476       417812       658811
# bridgeville         0.44803       0.115586       509125  1.25445e+06
# flower             0.498981       0.199109  1.68364e+06   2.2047e+06
#
#                RMS_mean     RMS_std  n_faces
# clip
# ocean's 11   0.00952785  0.00996102     84.0
# dreary       0.00611669  0.00372078      0.0
# garden        0.0220961   0.0117548     28.0
# hotel        0.00236509  0.00425779     25.0
# inception     0.0281695   0.0305206     84.0
# brokovich     0.0108872  0.00953885     49.0
# star wars     0.0192851   0.0164125     10.0
# two men       0.0214162   0.0184442     25.0
# pockets       0.0160316  0.00540246     36.0
# home alone   0.00638985   0.0116077     21.0
# social net    0.0068364  0.00560713    106.0
# bridgeville   0.0216791   0.0133741     69.0
# flower        0.0344292   0.0147239      1.0

# %%
x = result["n_faces"]
y = np.array(cogn_median_vals).squeeze()

print(sp.stats.pearsonr(x.values,y))
print(sp.stats.spearmanr(x.values,y))

r,p = sp.stats.pearsonr(x.values, y)

fig, ax = plt.subplots(figsize=(10,10))
color='black'
ax.scatter(x,y,color=color)
sns.regplot(x=x, y=y, ax=ax, color='gray', scatter=False, truncate=False) # use Seaborn to get the line of best fit, but not the points

labels = [ax.annotate(txt, (x[i], y[i])) for i,txt in enumerate(x.index)]
adjust_text(labels)

ax.annotate(f"r = {r:.2f}", xy=(0.1, 0.9), xycoords='axes fraction', color=color)

ax.set_xlabel("Number of TRs containing at least one face")
ax.set_ylabel("Cognition r(obs, pred)")
# Out:
# (0.7612591746753985, 0.0025039139614560584)
# SpearmanrResult(correlation=0.6887078474798858, pvalue=0.009235079230237172)
# Text(56.75, 0.5, 'Cognition r(obs, pred)')

# %%
result_plus_acc = result.copy()
result_plus_acc["pred_acc"] = cogn_median_vals.rename(index=rename_dict)
result_plus_acc
# Out:
#             Brightness_mean Brightness_std Optflow_mean  Optflow_std  \
# clip
# ocean's 11         0.194174      0.0450095       308742       597097
# dreary             0.345002       0.180715       461704       744793
# garden             0.501991       0.118884  1.93431e+06   2.1952e+06
# hotel              0.441508       0.111025       310332       435640
# inception          0.224016      0.0425352  1.94851e+06  1.22648e+06
# brokovich           0.50126       0.109313  2.33156e+06  2.35933e+06
# star wars           0.48454       0.123043  1.45776e+06  1.43572e+06
# two men            0.355873       0.102981  1.17398e+06  2.04192e+06
# pockets            0.535599      0.0778494       379944       481523
# home alone         0.232775      0.0584691       659901       834770
# social net         0.144997      0.0402476       417812       658811
# bridgeville         0.44803       0.115586       509125  1.25445e+06
# flower             0.498981       0.199109  1.68364e+06   2.2047e+06
#
#                RMS_mean     RMS_std  n_faces  pred_acc
# clip
# ocean's 11   0.00952785  0.00996102     84.0  0.342261
# dreary       0.00611669  0.00372078      0.0  0.040545
# garden        0.0220961   0.0117548     28.0  0.182495
# hotel        0.00236509  0.00425779     25.0  0.141923
# inception     0.0281695   0.0305206     84.0  0.222143
# brokovich     0.0108872  0.00953885     49.0  0.187331
# star wars     0.0192851   0.0164125     10.0  0.211377
# two men       0.0214162   0.0184442     25.0  0.180369
# pockets       0.0160316  0.00540246     36.0  0.216468
# home alone   0.00638985   0.0116077     21.0  0.198027
# social net    0.0068364  0.00560713    106.0  0.379092
# bridgeville   0.0216791   0.0133741     69.0  0.120825
# flower        0.0344292   0.0147239      1.0  0.051353

# %%
import pingouin as pg
pg.partial_corr(data = result_plus_acc, x = "n_faces", y = "pred_acc", covar="Brightness_std", method='pearson')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-764543effc3d> in <module>()
#       1 import pingouin as pg
# ----> 2 pg.partial_corr(data = result_plus_acc, x = "n_faces", y = "pred_acc", covar="Brightness_std", method='pearson').round(3)
#
# ~/anaconda3/lib/python3.6/site-packages/pingouin/correlation.py in partial_corr(data, x, y, covar, x_covar, y_covar, tail, method)
#     726     assert all([c in data for c in col]), 'columns are not in dataframe.'
#     727     # Check that columns are numeric
# --> 728     assert all([data[c].dtype.kind in 'bfiu' for c in col])
#     729
#     730     # Drop rows with NaN
#
# AssertionError:

# %%
X = result_plus_acc[["n_faces","Brightness_std"]]
Y = result_plus_acc["pred_acc"]

print(X.shape)
print(Y.shape)

reg = LinearRegression(fit_intercept=False, normalize=True)
reg.fit(X,Y)

reg.coef_
# Out:
# (13, 2)
# (13,)
# array([0.00311097, 0.49142669])

# %%
import statsmodels.api as sm

X = np.array(result_plus_acc[["n_faces","Brightness_std"]], dtype='float')
X = np.array(sm.add_constant(X))

y = np.array(result_plus_acc["pred_acc"])


model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     17.03
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):           0.000602
# Time:                        16:10:42   Log-Likelihood:                 22.213
# No. Observations:                  13   AIC:                            -38.43
# Df Residuals:                      10   BIC:                            -36.73
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2978      0.071      4.223      0.002       0.141       0.455
# x1             0.0007      0.001      0.996      0.343      -0.001       0.002
# x2            -1.3203      0.452     -2.920      0.015      -2.328      -0.313
# ==============================================================================
# Omnibus:                        0.198   Durbin-Watson:                   2.520
# Prob(Omnibus):                  0.906   Jarque-Bera (JB):                0.390
# Skew:                          -0.067   Prob(JB):                        0.823
# Kurtosis:                       2.162   Cond. No.                     1.74e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.74e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/finnes/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1604: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   "anyway, n=%i" % int(n))

# %%
y
# Out:
# array([0.34226062, 0.04054479, 0.18249505, 0.14192274, 0.22214286,
#        0.18733106, 0.21137684, 0.1803687 , 0.21646819, 0.19802663,
#        0.37909201, 0.12082545, 0.05135263])

# %%
x = result["n_faces"]
y = isc_std

print(sp.stats.pearsonr(x,np.array(y))) # .reshape(-1,1)))
print(sp.stats.spearmanr(x,np.array(y)))

plt.scatter(x,y)
# Out:
# (0.3235584059474193, 0.2808519387604568)
# SpearmanrResult(correlation=0.3939408887584947, pvalue=0.18289688316516475)

# %%
clip_list
# Out:
# Index(['oceans', 'dreary', 'garden', 'hotel', 'inception', 'brokovich',
#        'starwars', 'twomen', 'pockets', 'homealone', 'socialnet',
#        'bridgeville', 'flower'],
#       dtype='object', name='clip')

# %%
result
# Out:
#             Brightness_mean Brightness_std Optflow_mean  Optflow_std  \
# clip
# ocean's 11         0.194174      0.0450095       308742       597097
# dreary             0.345002       0.180715       461704       744793
# garden             0.501991       0.118884  1.93431e+06   2.1952e+06
# hotel              0.441508       0.111025       310332       435640
# inception          0.224016      0.0425352  1.94851e+06  1.22648e+06
# brokovich           0.50126       0.109313  2.33156e+06  2.35933e+06
# star wars           0.48454       0.123043  1.45776e+06  1.43572e+06
# two men            0.355873       0.102981  1.17398e+06  2.04192e+06
# pockets            0.535599      0.0778494       379944       481523
# home alone         0.232775      0.0584691       659901       834770
# social net         0.144997      0.0402476       417812       658811
# bridgeville         0.44803       0.115586       509125  1.25445e+06
# flower             0.498981       0.199109  1.68364e+06   2.2047e+06
#
#                RMS_mean     RMS_std  n_faces
# clip
# ocean's 11   0.00952785  0.00996102     84.0
# dreary       0.00611669  0.00372078      0.0
# garden        0.0220961   0.0117548     28.0
# hotel        0.00236509  0.00425779     25.0
# inception     0.0281695   0.0305206     84.0
# brokovich     0.0108872  0.00953885     49.0
# star wars     0.0192851   0.0164125     10.0
# two men       0.0214162   0.0184442     25.0
# pockets       0.0160316  0.00540246     36.0
# home alone   0.00638985   0.0116077     21.0
# social net    0.0068364  0.00560713    106.0
# bridgeville   0.0216791   0.0133741     69.0
# flower        0.0344292   0.0147239      1.0

# %%
data = pd.DataFrame(index=clip_list, dtype='float')
data["EyeISC_std"] = isc_std
data["n_faces"] = result.loc[clip_list, "n_faces"].values.astype(float)
data["r"] = cogn_median_vals.loc[clip_list].values.astype(float)

mediation_analysis(data=data, x="n_faces", m = "EyeISC_std", y="r")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-0868a2a71ea1> in <module>()
#       1 data = pd.DataFrame(index=clip_list, dtype='float')
#       2 data["EyeISC_std"] = isc_std
# ----> 3 data["n_faces"] = result.loc[clip_list, "n_faces"].values.astype(float)
#       4 data["r"] = cogn_median_vals.loc[clip_list].values.astype(float)
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1419                     return section
#    1420                 # This is an elided recursive call to iloc/loc/etc'
# -> 1421                 return getattr(section, self.name)[new_key]
#    1422
#    1423         raise IndexingError("not applicable")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1653             if not (ax.is_categorical() or ax.is_interval()):
#    1654                 raise KeyError(
# -> 1655                     "Passing list-likes to .loc or [] with any missing labels "
#    1656                     "is no longer supported, see "
#    1657                     "https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"  # noqa:E501
#
# KeyError: 'Passing list-likes to .loc or [] with any missing labels is no longer supported, see https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike'

# %%
cols_of_interest = ["Brightness_mean", "Brightness_std", "Optflow_mean", "Optflow_std", "RMS_mean", "RMS_std", "n_faces"]

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(result[cols_of_interest].astype(float).corr(), annot=True, square=True, ax=ax, cmap='RdBu_r', center=0)

# %%
cols_of_interest = ["n_faces", 
                    # "Brightness_mean", "Brightness_std", 
                    "Optflow_mean", "Optflow_std", 
                    "RMS_mean", "RMS_std"]

X = result[cols_of_interest]
Y = cogn_median_vals.values

pls = PLSRegression(n_components=1)
pls.fit(X, Y)
# Out:
# PLSRegression(copy=True, max_iter=500, n_components=1, scale=True, tol=1e-06)

# %%
plt.scatter(Y, pls.predict(X))

# %%
X
# Out:
#              n_faces Optflow_mean  Optflow_std    RMS_mean     RMS_std
# clip
# oceans          84.0       308742       597097  0.00952785  0.00996102
# dreary           0.0       461704       744793  0.00611669  0.00372078
# garden          28.0  1.93431e+06   2.1952e+06   0.0220961   0.0117548
# hotel           25.0       310332       435640  0.00236509  0.00425779
# inception       84.0  1.94851e+06  1.22648e+06   0.0281695   0.0305206
# brokovich       49.0  2.33156e+06  2.35933e+06   0.0108872  0.00953885
# starwars        10.0  1.45776e+06  1.43572e+06   0.0192851   0.0164125
# twomen          25.0  1.17398e+06  2.04192e+06   0.0214162   0.0184442
# pockets         36.0       379944       481523   0.0160316  0.00540246
# homealone       21.0       659901       834770  0.00638985   0.0116077
# socialnet      106.0       417812       658811   0.0068364  0.00560713
# bridgeville     69.0       509125  1.25445e+06   0.0216791   0.0133741
# flower           1.0  1.68364e+06   2.2047e+06   0.0344292   0.0147239

# %%
X.columns[pls.x_loadings_.flatten().argsort()]
# Out:
# Index(['Optflow_std', 'Optflow_mean', 'RMS_mean', 'RMS_std', 'n_faces'], dtype='object')

# %%
X.columns
# Out:
# Index(['n_faces', 'Optflow_mean', 'Optflow_std', 'RMS_mean', 'RMS_std'], dtype='object')

# %%
pls.x_weights_
# Out:
# array([[ 0.84975035],
#        [-0.20231481],
#        [-0.36289619],
#        [-0.3243403 ],
#        [ 0.01013856]])

# %%
pls.x_loadings_
# Out:
# array([[ 0.62597279],
#        [-0.50614588],
#        [-0.59863119],
#        [-0.46454659],
#        [-0.22030348]])

# %%
reg = LinearRegression(fit_intercept=True)
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(Y, reg.predict(X))

# %%
X.columns
# Out:
# Index(['n_faces', 'Optflow_mean', 'Optflow_std', 'RMS_mean', 'RMS_std'], dtype='object')

# %%
X.index
# Out:
# Index(['oceans', 'dreary', 'garden', 'hotel', 'inception', 'brokovich',
#        'starwars', 'twomen', 'pockets', 'homealone', 'socialnet',
#        'bridgeville', 'flower'],
#       dtype='object', name='clip')

# %%
cogn_median_vals.index
# Out:
# Index(['oceans', 'dreary', 'garden', 'hotel', 'inception', 'brokovich',
#        'starwars', 'twomen', 'pockets', 'homealone', 'socialnet',
#        'bridgeville', 'flower'],
#       dtype='object', name='clip')

# %%
reg.coef_
# Out:
# array([[-1.77257086e-01, -1.81589873e+00,  2.33440332e-08,
#          1.31454627e-08,  3.45024840e+00, -7.92925741e+00,
#          1.93652721e-04]])

# %%
X.columns[reg.coef_.argsort()]
# Out:
# /Users/finnes/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Support for multi-dimensional indexing (e.g. `index[:, None]`) on an Index is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   """Entry point for launching an IPython kernel.
# array([['RMS_std', 'Brightness_std', 'Brightness_mean', 'Optflow_std',
#         'Optflow_mean', 'n_faces', 'RMS_mean']], dtype=object)

# %%
weights = reg.coef_.flatten().T
weights
# Out:
# array([-1.77257086e-01, -1.81589873e+00,  2.33440332e-08,  1.31454627e-08,
#         3.45024840e+00, -7.92925741e+00,  1.93652721e-04])

# %%
print("Highest loadings:")
print(labels.value[pls.x_loadings_[:,0].argsort()[::-1][:15]])

print("Lowest loadings:")
print(labels.value[pls.x_loadings_[:,0].argsort()[:15]])
# Out:
# Highest loadings:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-c8e243d57046> in <module>()
#       1 print("Highest loadings:")
# ----> 2 print(labels.value[pls.x_loadings_[:,0].argsort()[::-1][:15]])
#       3
#       4 print("Lowest loadings:")
#       5 print(labels.value[pls.x_loadings_[:,0].argsort()[:15]])
#
# AttributeError: 'list' object has no attribute 'value'

# %% [markdown]
# ## Look at Motion Energy Features

# %%
f = h5py.File('/Users/finnes/Documents/HCP_7T/7T_movie_resources/MotionEnergyFeatures.hdf5', 'r')
list(f.keys())
# Out:
# ['MOVIE1_CC1',
#  'MOVIE1_CC1_est',
#  'MOVIE1_CC1_val',
#  'MOVIE2_HO1',
#  'MOVIE2_HO1_est',
#  'MOVIE2_HO1_val',
#  'MOVIE3_CC2',
#  'MOVIE3_CC2_est',
#  'MOVIE3_CC2_val',
#  'MOVIE4_HO2',
#  'MOVIE4_HO2_est',
#  'MOVIE4_HO2_val',
#  'gabor_parameters']

# %%
labels = f["gabor_parameters"]
print(labels)
# Out:
# <HDF5 dataset "gabor_parameters": shape (6, 4025), type "<f4">

# %% [markdown]
# 1 - x position
#
# 2 - y position
#
# 3 - direction of motion (or orientation)
#
# 4 - spatial frequency
#
# 5 - temporal frequency
#
# 6 - Gaussian envelope size

# %%
fig, axes = plt.subplots(2,3, figsize=(12,6))

sns.set(font_scale=1)
params = ["x-pos", "y-pos", "mot_dir", "spatial_freq", "temporal_freq", "Gaussian_env_size"]

for label in range(labels.shape[0]):
    ax = axes.flatten()[label]
    sns.heatmap(np.atleast_2d(labels.value[label,:]), ax=ax)
    ax.set_title(params[label])
    
fig.tight_layout()

# %%
dset = f["MOVIE1_CC1"]
print(dset.shape)
print(dset.dtype)
# Out:
# (921, 4025)
# float64

# %%
n_clips = len(video_tr_lookup["clip_name"])
n_features = labels.shape[1]

df = pd.DataFrame(np.zeros((n_clips, n_features)), index=video_tr_lookup["clip_name"])

for run_name in ["MOVIE1_CC1", "MOVIE2_HO1", "MOVIE3_CC2", "MOVIE4_HO2"]:
    run_short_name = run_name.split('_')[0]
    
    dset = f[run_name]
    movie_trs = f[run_name+"_est"].value + f[run_name+"_val"].value
    clipwise_trs = [[i for i,value in it] for key,it in itertools.groupby(enumerate(movie_trs), key=operator.itemgetter(1)) if key != 0]
    
    n_trs = 143

    for clip_no in range(len(clipwise_trs)):
        clip_name = video_tr_lookup[(video_tr_lookup["run"].str.contains(run_short_name)) & (video_tr_lookup["clipno_in_run"]==clip_no+1)]["clip_name"]
        print(dset.value[clipwise_trs[clip_no][:143]].shape)
        mean_features = dset.value[clipwise_trs[clip_no][:143]].mean(axis=0)
        df.loc[clip_name,:] = mean_features
# Out:
# (143, 4025)
# (143, 4025)
# (143, 4025)
# (58, 4025)
# (77, 4025)
# (143, 4025)
# (143, 4025)
# (143, 4025)
# (77, 4025)
# (143, 4025)
# (143, 4025)
# (143, 4025)
# (136, 4025)
# (77, 4025)
# (143, 4025)
# (143, 4025)
# (143, 4025)
# (77, 4025)

# %%
df.shape
# Out:
# (18, 4025)

# %%
labels.shape[1]
# Out:
# 4025

# %%
X = df[cogn_median_vals.notna().values]
Y = cogn_median_vals[cogn_median_vals.notna().values]

reg = LinearRegression(fit_intercept=False, normalize=True)
reg.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=True)

# %%
reg.coef_.squeeze().shape
# Out:
# (4025,)

# %%
plt.plot(np.sort(reg.coef_).T)

# %%
tt = np.array([1, 7, 3, 9, 4])
print(tt.shape)
tt.argsort()[0]
# Out:
# (5,)
# 0

# %%
reg.coef_.squeeze().argsort()[::-1]
# Out:
# array([1201, 2776,  182, ..., 1589, 2851, 3468])

# %%
top_channels = reg.coef_.squeeze().argsort()[::-1][:10]
print(len(top_channels))
print(top_channels[:])
top_channels
# Out:
# 10
# [1201 2776  182 2777  797 2781 1205 1202 2263 3838]
# array([1201, 2776,  182, 2777,  797, 2781, 1205, 1202, 2263, 3838])

# %%
def select(lst, *indices):
    return (lst[i] for i in indices)

# %%
feats = []

for channel in top_channels:
    feats.append(labels.value[:,channel])

# %%
np.array(feats).squeeze().shape
# Out:
# (10, 6)

# %%
sns.heatmap([labels.value[:,x] for x in top_channels])

# %%
[labels.value[:,x] for x in top_channels]
# Out:
# [array([8.9375001e-01, 3.1333333e-01, 4.5000000e+01, 1.0666667e+00,
#         1.9999920e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 4.5000000e+01, 1.0666667e+00,
#         4.0000081e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 4.5000000e+01, 1.0666667e+00,
#         0.0000000e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 9.0000000e+01, 1.0666667e+00,
#         4.0000081e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 4.5000000e+01, 2.1333334e+00,
#         0.0000000e+00, 1.8750001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 2.7000000e+02, 1.0666667e+00,
#         4.0000081e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 2.2500000e+02, 1.0666667e+00,
#         1.9999920e+00, 3.7500001e-02], dtype=float32),
#  array([8.9375001e-01, 3.1333333e-01, 9.0000000e+01, 1.0666667e+00,
#         1.9999920e+00, 3.7500001e-02], dtype=float32),
#  array([8.2812500e-01, 6.8666667e-01, 4.5000000e+01, 2.1333334e+00,
#         1.9999920e+00, 1.8750001e-02], dtype=float32),
#  array([8.2812500e-01, 6.8666667e-01, 4.5000000e+01, 2.1333334e+00,
#         4.0000081e+00, 1.8750001e-02], dtype=float32)]

# %%
fig, axes = plt.subplots(2,3, figsize=(12,6))

params = ["x-pos", "y-pos", "mot_dir", "spatial_freq", "temporal_freq", "Gaussian_env_size"]

for channel in top_channels:
    labels.value
for label in range(labels.shape[0]):
    ax = axes.flatten()[label]
    sns.heatmap(np.atleast_2d([labels.value[label,x] for x in top_channels]), ax=ax)
    ax.set_title(params[label])
    
fig.tight_layout()

# %%
from nimare import decode
# Out:
# /Users/finnes/anaconda3/lib/python3.6/site-packages/nimare/decode/__init__.py:17: ImportWarning: nimare.decode is an experimental module under active development; use it at your own risk.
#   ImportWarning

# %%
decode.discrete.neurosynth_decode([-10,84,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d8c2474d24ec> in <module>()
# ----> 1 decode.discrete.neurosynth_decode([-10,84,6])
#
# TypeError: neurosynth_decode() missing 2 required positional arguments: 'annotations' and 'ids'
